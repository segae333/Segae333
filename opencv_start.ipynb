# %%
import cv2
import numpy as np
import sys

# %%
img = cv2.imread('./fig/puppy.bmp', cv2.WINDOW_NORMAL)
print('img shape =', img.shape)

if img is None :
    print('image read failed')
    sys.exit()
    
cv2.namedWindow('puppy', cv2.WINDOW_AUTOSIZE)
cv2.imshow('puppy', img)

img_resize = cv2.resize(img, (1200, 600), cv2.INTER_AREA)
cv2.imwrite('./fig/puppy_resize.png')
while True :
#    if cv2.waitKey() == 27 :
#        break
    if cv2.waitKey(1000) == ord('q') :
        break
    
cv2.destroyAllWindows()
# Out:
# img shape = (480, 640)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-3-0a6349f30cdb> in <module>
#      10
#      11 img_resize = cv2.resize(img, (1200, 600), cv2.INTER_AREA)
# ---> 12 cv2.imwrite('./fig/puppy_resize.png')
#      13 while True :
#      14 #    if cv2.waitKey() == 27 :
#
# error: OpenCV(4.5.4-dev) :-1: error: (-5:Bad argument) in function 'imwrite'
# > Overload resolution failed:
# >  - imwrite() missing required argument 'img' (pos 2)
# >  - imwrite() missing required argument 'img' (pos 2)
# Exception in callback BaseSelectorEventLoop._read_from_self()
# handle: <Handle BaseSelectorEventLoop._read_from_self()>
# Traceback (most recent call last):
#   File "C:\Users\segaeshin\Anaconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
# ...

# %%
import matplotlib.pyplot as plt

# %%
imgBGR = cv2.imread('./fig/puppy.bmp', cv2.IMREAD_GRAYSCALE)

if imgBGR is None :
    print('img read failed')
    sys.exit()
    
# imgRGB = cv2.cvtColor(imgBGR, cv2.COLOR_BGR2RGB)
plt.imshow(imgBGR, cmap = 'gray')
plt.axis('off')
plt.show()

# %%
import glob

# %%
img_list = glob.glob('./fig/images/*.jpg')

cv2.namedWindow('scene')
cv2.setWindowProperty('scene', cv2.WND_PROP_FULLSCREEN,
                     cv2.WINDOW_FULLSCREEN)

indx = 0
while True :
    img = cv2.imread(img_list[indx])
    
    cv2.imshow('scene', img)
    
    if cv2.waitKey(1000) == 27 :
        break
        
    indx += 1
    
    if indx >=5 :
        indx = 0
    
cv2.destroyAllWindows()

# %%
## 

img1 = cv2.imread('./fig/puppy.bmp', cv2.IMREAD_GRAYSCALE)
img2 = cv2.imread('./fig/puppy_1280_853.jpg', cv2.IMREAD_ANYCOLOR)

# print('img1 = ', img1.shape)
# print('img2 = ', img2.shape)

# print('img1 = ', img1.dtype)
# print('img2 = ', img2.dtype)

height, width = img2.shape[:2]
print(height)
# cv2.namedWindow('puppy', cv2.WINDOW_AUTOSIZE)
# cv2.imshow('puppy', img1)

# while True :
#     if cv2.waitKey() == 27 :
#         break
    
#cv2.destroyAllWindows()
# Out:
# 853

# %%
# circle(img, center, radius, color, [, thickness[, lineType[, shift]]]) -> img
# . @brief Draws a circle 
img = np.ones((480, 640, 3), dtype = np.uint8)*255

cv2.circle(img, (200, 200), 150,(0, 0, 255),4, cv2.LINE_8 )

cv2.imshow('image', img)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
# 이미지 합성하기 
src = cv2.imread('./fig/fig/airplane.bmp', cv2.IMREAD_COLOR)
mask = cv2.imread('./fig/fig/mask_plane.bmp', cv2.IMREAD_GRAYSCALE)
dst = cv2.imread('./fig/fig/field.bmp', cv2.IMREAD_COLOR)


#cv2.copyTo(src, mask, dst)
#dst = cv2.copyTo(src, mask, dst)

cv2.imshow('src', src)
cv2.imshow('mask', mask)
cv2.imshow('dst', dst)

cv2.waitKey()
cv2.destroyAllWindows()

# %%
src = cv2.imread('./fig/puppy.bmp')
# 알파채널 까지 읽을땐 uncanged옵션을 써 줘야 한다. 
sunglass = cv2.imread('./fig/fig/imgbin_sunglasses_1.png', cv2.IMREAD_UNCHANGED)

sunglass = cv2.resize(sunglass, (300, 150))

mask = sunglass[:, :, 3]
glass = sunglass[:, :, 0:3]

h, w = mask.shape[:2]
crop = src[120:120+h, 220:220 + w]

#cv2.copyTo(glass, mask, crop)
crop[mask > 0 ] = (0, 0, 255)

cv2.imshow('src', src)
# cv2.imshow('glass', sunglass)
cv2.imshow('mask', mask)
cv2.imshow('crop', crop)

cv2.waitKey()
cv2.destroyAllWindows()
